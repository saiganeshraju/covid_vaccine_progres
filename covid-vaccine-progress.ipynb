# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv')
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20923 entries, 0 to 20922
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              20923 non-null  object
#  1   iso_code                             20923 non-null  object
#  2   date                                 20923 non-null  object
#  3   total_vaccinations                   11946 non-null  float64
#  4   people_vaccinated                    11170 non-null  float64
#  5   people_fully_vaccinated              8675 non-null   float64
#  6   daily_vaccinations_raw               9934 non-null   float64
#  7   daily_vaccinations                   20705 non-null  float64
#  8   total_vaccinations_per_hundred       11946 non-null  float64
#  9   people_vaccinated_per_hundred        11170 non-null  float64
#  10  people_fully_vaccinated_per_hundred  8675 non-null   float64
# ...

# %%
#looking for NULL values
df.isnull().sum(axis=0)
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                      8977
# people_vaccinated                       9753
# people_fully_vaccinated                12248
# daily_vaccinations_raw                 10989
# daily_vaccinations                       218
# total_vaccinations_per_hundred          8977
# people_vaccinated_per_hundred           9753
# people_fully_vaccinated_per_hundred    12248
# daily_vaccinations_per_million           218
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
#dropping souce_name & source_website
df.drop(['source_name', 'source_website'], axis=1, inplace=True)
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# dtype: object

# %%
#converting date to date
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# country                                        object
# iso_code                                       object
# date                                   datetime64[ns]
# total_vaccinations                            float64
# people_vaccinated                             float64
# people_fully_vaccinated                       float64
# daily_vaccinations_raw                        float64
# daily_vaccinations                            float64
# total_vaccinations_per_hundred                float64
# people_vaccinated_per_hundred                 float64
# people_fully_vaccinated_per_hundred           float64
# daily_vaccinations_per_million                float64
# vaccines                                       object
# dtype: object

# %%
#total vaccinations
df['total_vacc'] = df.groupby('country')['total_vaccinations'].tail(1)

#top 10 country with total vaccinations
x = df.groupby('country')['total_vacc'].mean().sort_values(ascending=False).head(10)

#bargraph
plt.figure(figsize=(7,7))
sns.set_theme(style="whitegrid")
sns.barplot(x=x.values, y=x.index, orient='h',palette='Blues_r')
plt.xlabel("Total Vaccinations")
plt.ylabel("Country")
print(x)
# Out:
# country
# China             602991000.0
# United States     292099778.0
# India             203166802.0
# Brazil             66432341.0
# United Kingdom     63349252.0
# England            53286560.0
# Germany            49255748.0
# France             34939982.0
# Italy              33555795.0
# Mexico             29239997.0
# Name: total_vacc, dtype: float64

# %%
#total people fully vaccinated
df['total_fully_vacc'] = df.groupby('country')['people_fully_vaccinated'].tail(1)

#top 10 country with total people fully vaccinated
x = df.groupby('country')['total_fully_vacc'].mean().sort_values(ascending=False).head(10)

#bargraph
plt.figure(figsize=(7,7))
sns.set_theme(style="whitegrid")
sns.barplot(x=x.values, y=x.index, orient='h',palette='Blues_r')
plt.xlabel("Total Fully Vaccinated")
plt.ylabel("Country")
print(x)
# Out:
# country
# United States     133532544.0
# India              42561240.0
# United Kingdom     24478052.0
# Brazil             21867556.0
# England            20777366.0
# Germany            14197101.0
# Turkey             12277313.0
# Mexico             12204779.0
# Russia             11781458.0
# Italy              11495551.0
# Name: total_fully_vacc, dtype: float64

# %%
#total people fully vaccinated per hundred
df['total_fully_vacc_per_100'] = df.groupby('country')['people_fully_vaccinated_per_hundred'].tail(1)

#top 10 country with total people fully vaccinated per hundred
x = df.groupby('country')['total_fully_vacc_per_100'].mean().sort_values(ascending=False).head(10)

#bargraph
plt.figure(figsize=(7,7))
sns.set_theme(style="whitegrid")
sns.barplot(x=x.values, y=x.index, orient='h',palette='Blues_r')
plt.xlabel("Total Fully Vaccinated Per Hundred")
plt.ylabel("Country")
print(x)
# Out:
# country
# Gibraltar           113.30
# Seychelles           65.11
# San Marino           61.70
# Israel               59.25
# Saint Helena         58.11
# Cayman Islands       56.12
# Bermuda              52.55
# Falkland Islands     50.96
# Aruba                47.21
# Malta                45.34
# Name: total_fully_vacc_per_100, dtype: float64

# %%
#total vaccinations
plt.figure(figsize=(10,10))
sns.lineplot(x='date', y='total_vaccinations', data=df)
plt.xlabel('Date')
plt.ylabel('Total Vaccinations')
# Out:
# Text(0, 0.5, 'Total Vaccinations')

# %%
#daily vaccinations trend
x = df.groupby('date')['daily_vaccinations'].sum()

plt.figure(figsize=(10,10))
sns.lineplot(x=x.index, y=x.values)
plt.title('Daily Vaccinations Trend')
plt.xlabel("Date")
plt.show()

# %%
#most common vaccines
df['vaccines'].value_counts()
# Out:
# Oxford/AstraZeneca                                                                    3670
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                         2985
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          1630
# Oxford/AstraZeneca, Pfizer/BioNTech                                                   1602
# Moderna, Pfizer/BioNTech                                                              1253
# Pfizer/BioNTech                                                                       1214
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                          1028
# Oxford/AstraZeneca, Sinopharm/Beijing                                                  905
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                      904
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                 403
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='vaccines', data=df, palette='Blues_r')
plt.ylabel('Vaccines')
plt.xlabel('Count')
plt.title('Most Common Vaccine Combinations Used')
plt.show()

# %%
#to be continued
